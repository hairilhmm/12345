# %% [markdown]
# <a href="https://colab.research.google.com/github/hairilhmm/12345/blob/main/Salinan_dari_belajar_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweet-preprocessor
# !pip install textblob
# !pip install sastrawi
# !pip install emoji
# !pip install PySastrawi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 2.5 MB/s eta 0:00:00
# ...
# ERROR: unknown command "install PySastrawi"

# %%
import os
import pandas as pd
import tweepy
import re
import string
from textblob import TextBlob
import preprocessor as p
from preprocessor.api import clean, tokenize, parse
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import datetime
from datetime import timedelta
Import numpy as np
import emoji
from Sastrawi.Stenner.StemmerFactory import StemmerFactory
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopwordRemoverFactory
# Out:
#   File "<ipython-input-2-2ee6637ce011>", line 14
#     Import numpy as np
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
def load_data():
  data = pd.read_csv('con4.csv')

# %%
tweet_df = load_data()

# %%
tweet_df = pd.DataFrame(tweet_df[['username', 'Rating', 'text']])
tweet_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6111887b5d92> in <cell line: 1>()
# ----> 1 tweet_df = pd.DataFrame(tweet_df[['username', 'Rating', 'text']])
#       2 tweet_df.head(10)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

#set warning
import warnings
warnings.filterwarnings('ignore')


pd.pandas.set_option('display.max_columns', None)

# %% [markdown]
# Cleaning

# %%
[6] #romove mention username dan Retweet
def remove_pattern(text, pattern_regex):
  r = re.findall(pattern_regex, text)
  for i in r:
    text = re.sub(i, '', text)
    return text

# %%
filename = "con4.csv"
df = pd.read_csv(filename, encoding = 'latin-1')
df.head()
# Out:
#           username Rating                                               text
# 0   Dian Septianto    5/5  Secara pelayanan, kebersihan, dan kenyamanan o...
# 1       SUGAR BOMM    5/5                       Cozy, nyaman untuk istirahat
# 2  Muhammad Ansori    5/5  Roomnya dan lingkungan sekelilingnya bersih, o...
# 3      Romie Pasha    5/5  Tempatnya nyaman homey banget, dengan gazebo m...
# 4     nelvi telvis    5/5  Homestay yang asri, dan homey banget, cocok bu...

# %%
tweet_df['clean_tweet']= np.vectorize(remove_pattern)(tweet_df['text'], " *RT* | *@[\w]*")
tweet_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-8f13240c00a0> in <cell line: 1>()
# ----> 1 tweet_df['clean_tweet']= np.vectorize(remove_pattern)(tweet_df['text'], " *RT* | *@[\w]*")
#       2 tweet_df.head()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

#set warning
import warnings
warnings.filterwarnings('ignore')


pd.pandas.set_option('display.max_columns', None)

# %%
filename = "con4.csv"
df = pd.read_csv(filename, encoding = 'latin-1')
df.head()
# Out:
#           username Rating                                               text
# 0   Dian Septianto    5/5  Secara pelayanan, kebersihan, dan kenyamanan o...
# 1       SUGAR BOMM    5/5                       Cozy, nyaman untuk istirahat
# 2  Muhammad Ansori    5/5  Roomnya dan lingkungan sekelilingnya bersih, o...
# 3      Romie Pasha    5/5  Tempatnya nyaman homey banget, dengan gazebo m...
# 4     nelvi telvis    5/5  Homestay yang asri, dan homey banget, cocok bu...

# %%
#rumus preprocessing
import re, string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-93231b1c-881a-4b59-8c4b-7551ac32132a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93231b1c-881a-4b59-8c4b-7551ac32132a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_penerima = pd.read_csv('con4.csv')
df_penerima .head()
# Out:
#           username Rating                                               text
# 0   Dian Septianto    5/5  Secara pelayanan, kebersihan, dan kenyamanan o...
# 1       SUGAR BOMM    5/5                       Cozy, nyaman untuk istirahat
# 2  Muhammad Ansori    5/5  Roomnya dan lingkungan sekelilingnya bersih, o...
# 3      Romie Pasha    5/5  Tempatnya nyaman homey banget, dengan gazebo m...
# 4     nelvi telvis    5/5  Homestay yang asri, dan homey banget, cocok bu...

# %%
def preprocessing(text):
    text = text.lower()
    text=text.strip()
    text=re.compile('<.*>').sub('', text)
    text = re.compile('[%s]' % re.escape(string.punctuation)).sub(' ', text)
    text = re.sub('\s+',' ', text)
    text = re.sub(r'\[[0-9]*\]','',text)
    text=re.sub(r'[^\w\s]', '', str(text).lower().strip())
    text = re.sub(r'\d','',text)
    text = re.sub(r'\s+','',text)
    return text

# %%
#stopword removal
def stopwords(string):
    a= [i for i in string.split() if i not in stopwords.words('english')]
    return ' '.join(a)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip3 install googletrans==3.1.0a0
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 6.9 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16352 sha256=ca55a1a8a7946e207a1e49f59aca7e93dec3c4c2ac6fad499aafa8349d1c979f
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
import pandas as pd
import googletrans
from googletrans import Translator

# %%
df = pd.read_csv('con4.csv')
df.head(10)
# Out:
#            username Rating                                               text
# 0    Dian Septianto    5/5  Secara pelayanan, kebersihan, dan kenyamanan o...
# 1        SUGAR BOMM    5/5                       Cozy, nyaman untuk istirahat
# 2   Muhammad Ansori    5/5  Roomnya dan lingkungan sekelilingnya bersih, o...
# 3       Romie Pasha    5/5  Tempatnya nyaman homey banget, dengan gazebo m...
# 4      nelvi telvis    5/5  Homestay yang asri, dan homey banget, cocok bu...
# 5  Karel Firmansyah    5/5  Panjat pohon palem dan mangga\nAda bunga  menj...
# 6        Rahmad Jrs    4/5  Homestay yang nyaman, asri, ketersediaan air b...
# 7      Ocktap Riady    3/5  Home stay yang lumayan bagus. Cocok untuk kelu...
# 8      Gusti Arsita    5/5  Ibu nya baik, ramah, tempat bersih nyaman, fas...
# 9     Fachmi Wibowo    5/5  Sy di kamar family..Tempatnya Bersih Rapi..sar...

# %%
translator = Translator()
translations = {}
for column in df.columns:
  unique_elements = df[column].unique()
  for element in unique_elements:
    translations[element] = translator.translate(element).text
translations
# Out:
# {'Dian Septianto': 'Dian Septianto',
#  'SUGAR BOMM': 'SUGAR BOMB',
#  'Muhammad Ansori': 'Muhammad Ansori',
#  'Romie Pasha': 'Romie Pasha',
#  'nelvi telvis': 'nelvi telvos',
#  'Karel Firmansyah': 'Karel Firmansyah',
#  'Rahmad Jrs': 'Rahmad Jr',
#  'Ocktap Riady': 'Ocktap Riady',
#  'Gusti Arsita': 'Lord Arsita',
#  'Fachmi Wibowo': 'Fachmi Wibowo',
#  'Martin Rahmadi': 'Martin Rahmadi',
#  'Ipah Ajah': 'Ipah Ajah',
#  'Reinaldhi Julian': 'Reinaldhi Julian',
#  'Salsa Billa': 'Billa Sauce',
#  'Feren Alexi': 'Feren Alexi',
#  'Novriyadi andista': 'Novriyadi Andista',
#  'Syavira Rasulia': 'Syavira Rasuliya',
#  'Ayub Sulaiman': 'Job Solomon',
#  'Elga Tiwi': 'The ga toy',
#  'edonano30': "Edna's 30",
#  '5/5': '5/5',
#  '4/5': '4/5',
#  '3/5': '3/5',
# ...

# %%
df.replace(translations, inplace = True)
df.head(10)
# Out:
#            username Rating                                               text
# 0    Dian Septianto    5/5  In terms of service, cleanliness and comfort, ...
# 1        SUGAR BOMB    5/5                          Cozy, comfortable to rest
# 2   Muhammad Ansori    5/5  The room and surrounding environment are clean...
# 3       Romie Pasha    5/5  The place is very comfortable and homey, with ...
# 4      nelvi telvos    5/5  A beautiful and very homey homestay, suitable ...
# 5  Karel Firmansyah    5/5  Climb palm and mango trees\nThere are flowers ...
# 6         Rahmad Jr    4/5  A homestay that is comfortable, beautiful, has...
# 7      Ocktap Riady    3/5  A pretty good home stay. Suitable for small fa...
# 8       Lord Arsita    5/5  The mother is kind, friendly, clean comfortabl...
# 9     Fachmi Wibowo    5/5  I'm in the family room..The place is clean and...

# %%
df.to_csv('translate_investasi.csv',encoding='utf8', index=False)

# %%
import pandas as pd
def load_data():
  data = pd.read_csv('translate_investasi.csv')
  return data

# %%
tweet_df = load_data()
tweet_df.head()
# Out:
#           username Rating                                               text
# 0   Dian Septianto    5/5  In terms of service, cleanliness and comfort, ...
# 1       SUGAR BOMB    5/5                          Cozy, comfortable to rest
# 2  Muhammad Ansori    5/5  The room and surrounding environment are clean...
# 3      Romie Pasha    5/5  The place is very comfortable and homey, with ...
# 4     nelvi telvos    5/5  A beautiful and very homey homestay, suitable ...

# %%
# !pip install tweepy

# %%
from tweepy import OAuthHandler
import tweepy
import csv

# %%
# !pip install tweet_preprocessor
# !pip install texblob
# !pip install wordcloud
# !pip install nltk
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement texblob (from versions: none)
# ERROR: No matching distribution found for texblob
# ...

# %%
import preprocessor as p
from textblob import TextBlob
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as pd

# %%
data = pd.read_csv('translate_investasi.csv')

# %%
ps = PorterStemmer()

def stemming_data(x):
return ps.stem(x)

data['Tweet'] = data ['Tweet'].apply(stemming_data)
# Out:
#   File "<ipython-input-54-7a230b7a3c0a>", line 4
#     return ps.stem(x)
#     ^
# IndentationError: expected an indented block after function definition on line 3

# %%
data_tweet = list(data['tweet'])
polaritas = 0

status = []
total_positif = total negatif = total netral = total = 0

for i, tweet in enumerate(data_tweet):
analysis = TextBlob(tweet)
polaritas += analysis.polarity

if analysis.sentiment.polarity > 0.0:
  total_positif += 1
  status.append('Positif')
elif analysis.sentiment.polarity == 0.0:
   total_netral += 1
   status.append('Netral')
else:
  total_negatif += 1
  status.append('Negatif')

total += 1

print(f'Hasil Analisis Data:\nPositif = {total_positif}\nNetral = {total_netral}\nNegatif = {total_negatif}')
print(f'\nTotal Data : {total}')
# Out:
#   File "<ipython-input-55-bfa2495fb273>", line 5
#     total_positif = total negatif = total netral = total = 0
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# lexicon Based

# %%
# !pip install VaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
scores = [analyser.polarity_scores(x) for x in tweet_df['text']]
print(scores)
tweet_df['Compound_Score'] = [x['compound'] for x in scores]
# Out:
# [{'neg': 0.093, 'neu': 0.661, 'pos': 0.246, 'compound': 0.815}, {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.5106}, {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.7717}, {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.8653}, {'neg': 0.0, 'neu': 0.64, 'pos': 0.36, 'compound': 0.9559}, {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.5719}, {'neg': 0.0, 'neu': 0.632, 'pos': 0.368, 'compound': 0.872}, {'neg': 0.035, 'neu': 0.81, 'pos': 0.155, 'compound': 0.7807}, {'neg': 0.0, 'neu': 0.388, 'pos': 0.612, 'compound': 0.9118}, {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.8176}, {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.4019}, {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.7178}, {'neg': 0.0, 'neu': 0.362, 'pos': 0.638, 'compound': 0.974}, {'neg': 0.0, 'neu': 0.644, 'pos': 0.356, 'compound': 0.8555}, {'neg': 0.0, 'neu': 0.564, 'pos': 0.436, 'compound': 0.9134}, {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.8516}, {'neg': 0.0
# ...

# %%
tweet_df.head()
# Out:
#           username Rating                                               text
# 0   Dian Septianto    5/5  In terms of service, cleanliness and comfort, ...
# 1       SUGAR BOMB    5/5                          Cozy, comfortable to rest
# 2  Muhammad Ansori    5/5  The room and surrounding environment are clean...
# 3      Romie Pasha    5/5  The place is very comfortable and homey, with ...
# 4     nelvi telvos    5/5  A beautiful and very homey homestay, suitable ...

# %%
tweet_df.loc[tweet_df['Compound_Score'] < 0, 'Sentiments'] = 'Negatif'

tweet_df.loc[tweet_df['Compound_Score'] == 0, 'Sentiments'] = 'Netral'

tweet_df.loc[tweet_df['Compound_Score'] > 0, 'Sentiments'] = 'Positif'
tweet_df.head()
# Out:
#           username Rating                                               text  \
# 0   Dian Septianto    5/5  In terms of service, cleanliness and comfort, ...
# 1       SUGAR BOMB    5/5                          Cozy, comfortable to rest
# 2  Muhammad Ansori    5/5  The room and surrounding environment are clean...
# 3      Romie Pasha    5/5  The place is very comfortable and homey, with ...
# 4     nelvi telvos    5/5  A beautiful and very homey homestay, suitable ...
#
#    Compound_Score Sentiments
# 0          0.8150    Positif
# 1          0.5106    Positif
# 2          0.7717    Positif
# 3          0.8653    Positif
# 4          0.9559    Positif

# %%
tweet_df.to_csv('hasilinvestasi.csv', encoding='utf8', index=False)

# %% [markdown]
# rambo

# %%
# !pip install tweet-preprocessor
# !pip install textblob
# !pip install sastrawi
# !pip install emoji
# Out:
# ...
# /bin/bash: line 1: pip install emoji: command not found

# %%
import pandas as pd
def load_data():
  data = pd.read_csv('hasilinvestasi.csv')
  return data

# %%
tweet_df = load_data()
tweet_df.head()
# Out:
#           username Rating                                               text
# 0   Dian Septianto    5/5  In terms of service, cleanliness and comfort, ...
# 1       SUGAR BOMB    5/5                          Cozy, comfortable to rest
# 2  Muhammad Ansori    5/5  The room and surrounding environment are clean...
# 3      Romie Pasha    5/5  The place is very comfortable and homey, with ...
# 4     nelvi telvos    5/5  A beautiful and very homey homestay, suitable ...

# %%
s = pd.value_counts(tweet_df[ 'Sentiments'])
ax = s.plot.bar()
n = len(tweet_df.index)
print (n)
for p in ax.patches:
  ax.annotate(str(round(p.get_height() / n * 100, 2)) + '%', (p.get_x() * 1.005, p.get_height() * 1.005))
# Out:
# 20

# %%
wordcloud = WordCloud(width = 800, height = 800, background_color = 'black', max_words = 1000
                      , min_font_size = 20).generate(str(tweet_df))
fig = plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-26aa504378e8> in <cell line: 1>()
# ----> 1 wordcloud = WordCloud(width = 800, height = 800, background_color = 'black', max_words = 1000
#       2                       , min_font_size = 20).generate(str(tweet_df))
#       3 fig = plt.figure(figsize = (8,8), facecolor = None)
#       4 plt.imshow(wordcloud)
#       5 plt.axis("off")
#
# NameError: name 'WordCloud' is not defined

# %%
def generate_wordcloud(all_words):
global worldcloud
wordcloud = WordCloud(width=800, height=500, randon_state=21, max_font_size=100, relative_scaling=0.5, colormap='Dark'

plt.figure(figsize=(14, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
#   File "<ipython-input-61-a3f0b68ceeef>", line 2
#     global worldcloud
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# perhitungan akurasi

# %%
# !pip install VaderSentiment

# %% [markdown]
# Naive Bayes

# %%
# !pip install tweepy

# %%
from tweepy import OAuthHandler
import tweepy
import csv

# %%
# !pip install tweet-preprocessor
# !pip install textblob
# !pip install wordcloud
# !pip install nitk

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
 data = pd.read_csv('translate_investasi.csv')

# %%
ps = PorterStemmer()

def stemming_data(x):
  return ps.stem(x)

data['Tweet'] = data['text'].apply(stemming_data)

# %%
data_tweet = list(data['text'])
polaritas = 0

status = []
total_positif = total_negatif = total_netral = total = 0

for i, tweet in enumerate(data_tweet):
  analysis = TextBlob(tweet)
  polaritas += analysis.polarity

if analysis.sentiment.polarity > 0.0:
  total_positif += 1
  status.append('Positif')
elif analysis.sentiment.polarity == 0.0:
   total_netral += 1
   status.append('Netral')
else:
  total_negatif += 1
  status.append('Negatif')

total += 1

print(f'Hasil Analisis Data:\nPositif = {total_positif}\nNetral = {total_netral}\nNegatif = {total_negatif}')
print(f'\nTotal Data : {total}')
# Out:
# Hasil Analisis Data:
# Positif = 1
# Netral = 0
# Negatif = 0
#
# Total Data : 1

# %%
status = pd.DataFrame({'klasifikasi': status})
data['klasifikasi'] = status
data.tail()
# Out:
#              username Rating  \
# 15  Novriyadi Andista    5/5
# 16   Syavira Rasuliya    5/5
# 17        Job Solomon    5/5
# 18         The ga toy    5/5
# 19          Edna's 30    5/5
#
#                                                  text  \
# 15  The place is clean, cool, and the service is v...
# 16  The villa is very homey. Comfortable & clean. ...
# 17                     Homey.. privacy, quiet and fun
# 18  Really recommended for rest if on holiday to t...
# 19     Good, comfortable, friendly service, free WiFi
#
#                                                 Tweet klasifikasi
# 15  the place is clean, cool, and the service is v...         NaN
# 16  the villa is very homey. comfortable & clean. ...         NaN
# 17                     homey.. privacy, quiet and fun         NaN
# 18  really recommended for rest if on holiday to t...         NaN
# 19     good, comfortable, friendly service, free wifi         NaN

# %%
data.to_excel ('dataklasifikasi.xlsx',encoding='utf8', index=False)

# %%
def show_pie(label, data, legend_title) :
  fig, ax = plt.subplots(figsize=(8, 10), subplot_kw=dict(aspect='equal'))

  labels = [x.split()[-1] for x in label]

def func(pct, allvals):
  absolute = int(pct/100.*np.sum(allvals))
  return "{}:.1f}% ({:d})".format(pct, absolute)

  wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

  ax.legend(wedges, labels,
title=legend_title,
loc="center left",
bbox_to_anchor=(1, 0, 0.5, 1))

  plt.setp(autotexts, size=10, weight="bold")
plt.show()

# %%
label = ['Positif', 'Negatif', 'Netral']
count_data = [total_positif+1, total_negatif+1, total_netral]

show_pie(label, count_data, "Status")

# %% [markdown]
# Klasifikasi Naive Bayes

# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download('punk')
# Out:
# [nltk_data] Error loading punk: Package 'punk' not found in index
# False

# %%
dataset = data.drop([], axis=1, inplace=False)
dataset = [tuple(x) for x in dataset.to_records (index=False)]
data.head()
# Out:
#           username Rating                                               text
# 0   Dian Septianto    5/5  In terms of service, cleanliness and comfort, ...
# 1       SUGAR BOMB    5/5                          Cozy, comfortable to rest
# 2  Muhammad Ansori    5/5  The room and surrounding environment are clean...
# 3      Romie Pasha    5/5  The place is very comfortable and homey, with ...
# 4     nelvi telvos    5/5  A beautiful and very homey homestay, suitable ...

# %%
dataset = data.drop([], axis=1, inplace=False)
dataset = [tuple(x) for x in dataset.to_records (index=False)]
data.head()
# Out:
#           username Rating                                               text
# 0   Dian Septianto    5/5  In terms of service, cleanliness and comfort, ...
# 1       SUGAR BOMB    5/5                          Cozy, comfortable to rest
# 2  Muhammad Ansori    5/5  The room and surrounding environment are clean...
# 3      Romie Pasha    5/5  The place is very comfortable and homey, with ...
# 4     nelvi telvos    5/5  A beautiful and very homey homestay, suitable ...

# %%
import random

set_positif = []
set_negatif = []
set_netral = []

for n in dataset:
  if(n[1] == 'Positif'):
    set_positif.append(n)
  elif(n[1] == 'Negatif'):
    set_negatif.append(n)
else:
    set_netral.append(n)

set_positif = random.sample(set_positif, k=int(len(set_positif)/2))
set_negatif = random.sample(set_negatif, k=int(len(set_negatif)/2))
set_netral = random.sample(set_netral, k=int(len(set_netral)/2))
train = set_positif + set_negatif + set_netral
train_set = []
for n in train:
  train_set.append(n)

# %%
from textblob.classifiers import NaiveBayesClassifier
cl = NaiveBayesClassifier(train_set)
print('Akurasi Test:', cl.accuracy(dataset))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-93a3ccacfe37> in <cell line: 3>()
#       1 from textblob.classifiers import NaiveBayesClassifier
#       2 cl = NaiveBayesClassifier(train_set)
# ----> 3 print('Akurasi Test:', cl.accuracy(dataset))
#
# /usr/local/lib/python3.10/dist-packages/textblob/classifiers.py in accuracy(self, test_set, format)
#     264         else:  # test_set is a list of tuples
#     265             test_data = test_set
# --> 266         test_features = [(self.extract_features(d), c) for d, c in test_data]
#     267         return nltk.classify.accuracy(self.classifier, test_features)
#     268
#
# /usr/local/lib/python3.10/dist-packages/textblob/classifiers.py in <listcomp>(.0)
#     264         else:  # test_set is a list of tuples
#     265             test_data = test_set
# ...

# %%
data_tweet = list(data['text'])
polaritas = 0

status = []
total_positif = total_negatif = total_netral = total = 0

for i, tweet in enumerate(data_tweet):
  analysis = TextBlob(tweet, classifier=cl)

  if analysis.classify() == 'Positif':
    total_positif += 1
  elif analysis.classify() == 'Netral':
    total_netral += 1
else:
  total_negatif += 1

status.append(analysis.classify())
total += 1

print (f'\nHasil Analisis Data:\nPositif = {total_positif}\nNetral = {total_netral}\nNegatif = {total_negatif}')
print (f'\nTotal Data : {total}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-c54c063714e6> in <cell line: 7>()
#       8   analysis = TextBlob(tweet, classifier=cl)
#       9
# ---> 10   if analysis.classify() == 'Positif':
#      11     total_positif += 1
#      12   elif analysis.classify() == 'Netral':
#
# /usr/local/lib/python3.10/dist-packages/textblob/blob.py in classify(self)
#     434         if self.classifier is None:
#     435             raise NameError("This blob has no classifier. Train one first!")
# --> 436         return self.classifier.classify(self.raw)
#     437
#     438     @cached_property
#
# /usr/local/lib/python3.10/dist-packages/textblob/classifiers.py in classify(self, text)
#     249         """
#     250         text_features = self.extract_features(text)
# --> 251         return self.classifier.classify(text_features)
#     252
# ...

# %%
status = pd.DataFrame({'klasifikasi_bayes': status})
data['klasifikasi_bayes'] = status
data.tail()
# Out:
#              username Rating  \
# 15  Novriyadi Andista    5/5
# 16   Syavira Rasuliya    5/5
# 17        Job Solomon    5/5
# 18         The ga toy    5/5
# 19          Edna's 30    5/5
#
#                                                  text  klasifikasi_bayes
# 15  The place is clean, cool, and the service is v...                NaN
# 16  The villa is very homey. Comfortable & clean. ...                NaN
# 17                     Homey.. privacy, quiet and fun                NaN
# 18  Really recommended for rest if on holiday to t...                NaN
# 19     Good, comfortable, friendly service, free WiFi                NaN

# %%
data.to_excel('hasilinvestasii.xlsx',encoding='utf8', index=False)

# %%
s = pd.value_counts(data['klasifikasi_bayes'])
ax = s.plot.bar()
n = len(data.index)
print (n)
for p in ax.patches:
  ax.annotate(str(round(p.get_height() / n * 100, 2)) + '%', (p.get_x() * 1.005, p.get_height() * 1.005))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-113-e1cd31eeb926> in <cell line: 2>()
#       1 s = pd.value_counts(data['klasifikasi_bayes'])
# ----> 2 ax = s.plot.bar()
#       3 n = len(data.index)
#       4 print (n)
#       5 for p in ax.patches:
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1157         other axis represents a measured value.
#    1158         """
# -> 1159         return self(kind="bar", x=x, y=y, **kwargs)
#    1160
#    1161     @Appender(
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# ...

# %%
from wordcloud import WordCloud, STOPWORDS

wordcloud = WordCloud(width = 800, height = 800, background_color = 'black', max_words = 1000
                      , min_font_size = 20).generate(str(data))

#plot the word cloud
fig = plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
def generate_wordcloud(all_words):
  global Worldcloud
  wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=100, relative_scaling=0.5, colormap='Dark2'

  plt.figure(figsize=(14, 10))
  plt.imshow(wordcloud, interpolation="bilinear")
  plt.axis('off')
  plt.show()
# Out:
#   File "<ipython-input-122-705dd9ac69b1>", line 3
#     wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=100, relative_scaling=0.5, colormap='Dark2'
#                          ^
# SyntaxError: '(' was never closed
